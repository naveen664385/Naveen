# %%
#importing all the basic libraries
import numpy as np
import pandas as pd
import sklearn as sk
import matplotlib as mpt
# %matplotlib inline
import matplotlib.pyplot as plt
#load data into pandas datframe to see the structure of the data and analyze it
#skipping completely balnk lines and ignoring the lines with not having proper format
sample_data = pd.read_csv('C:/Users/bnaveen3/Desktop/Data Set DA.csv',skip_blank_lines=True,
                      error_bad_lines=False)

# %%
sample_data['los'].plot.pie()
np.median(sample_data['los'])
#np.std(sample_data['los'])
# Out:
# 4.0

# %%
from scipy.stats import skew
skew(sample_data['los'])
# Out:
# 2.0190713784805534

# %%
plt.figure(figsize=(10,5))
plt.figure(xlabel='na')
plt.scatter(sample_data['age'],sample_data['los'],title='age')
np.cov(sample_data['los'],sample_data['diabetes'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-a6c408fbcb2e> in <module>()
#       1 plt.figure(figsize=(10,5))
# ----> 2 plt.figure(xlabel='na')
#       3 plt.scatter(sample_data['age'],sample_data['los'],title='age')
#       4 np.cov(sample_data['los'],sample_data['diabetes'])
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#     546                                         frameon=frameon,
#     547                                         FigureClass=FigureClass,
# --> 548                                         **kwargs)
#     549
#     550         if figLabel:
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backend_bases.py in new_figure_manager(cls, num, *args, **kwargs)
#     158         from matplotlib.figure import Figure
# ...

# %%
sample_data[['age']].plot.hist()
